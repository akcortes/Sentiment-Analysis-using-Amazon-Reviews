# %%
import pandas as pd
import numpy as np

#import pyLDAvis.gensim 
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline

from sklearn.feature_extraction import text
from sklearn.feature_extraction.text import CountVectorizer
import pickle

#STTM
from gsdmm import MovieGroupProcess
# Custom python scripts for preprocessing, prediction and
# visualization
#from visualisation import plot_topic_notebook

import nltk
from nltk.corpus import stopwords
from nltk import FreqDist

from wordcloud import WordCloud, STOPWORDS 

from sklearn.feature_extraction import text
from sklearn.feature_extraction.text import CountVectorizer
import pickle

from PIL import Image
import requests
import json
import re

from gensim import matutils, models
import gensim 
from gensim import corpora 
from gensim.models.coherencemodel import CoherenceModel

# libraries for visualization 
import pyLDAvis 
import pyLDAvis.gensim_models

import scipy.sparse

import warnings
warnings.filterwarnings("ignore")
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
data = pd.read_csv('data_final.csv')
data.head()
# Out:
#    Unnamed: 0  stars                                               text  \
# 0           0      5   work well rosacea skin rosacea ocular rosacea...
# 1           1      5   refresh absolutely love refresh leaf skin fee...
# 2           2      5   perfect sensitive skin love recommend beautic...
# 3           3      1   defective spray tip productive spray try remo...
# 4           4      5                                   nice soothe cool
#
#    stopwords  punctuation  numerics  upper  word_count  char_count  avg_word  \
# 0         28           10         0      3          36         208       4.9
# 1         13            5         0      1          24         145       5.3
# 2          9            4         0      0          15          91       5.5
# 3         47           16         0      5          53         348       5.7
# 4          1            1         0      0           4          17       4.7
#
#    polarity  subjectivity
# 0  0.178571      0.642857
# 1  0.292857      0.480952
# 2  0.425000      0.633333
# 3 -0.010438      0.370640
# 4  0.475000      0.825000

# %%
data = data.drop(columns='Unnamed: 0')

# %%
# new df with good reviews
good_reviews = data[(data.polarity > 0.7)]
print(len(good_reviews))

# new df with good reviews
bad_reviews = data[(data.polarity < 0)]
print(len(bad_reviews))
# Out:
# 47
# 38

# %%
# define corpus
corpus = []
corpus = data['text'].str.split()
corpus = corpus.values.tolist()

# %% [markdown]
# # LDA

# %%
dic = gensim.corpora.Dictionary(corpus)
bow_corpus = [dic.doc2bow(doc) for doc in corpus]

# %%
lda_model = gensim.models.LdaMulticore(bow_corpus, 
                                   num_topics = 7, 
                                   id2word = dic,                                    
                                   passes = 10)
lda_model.show_topics()
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)
# /opt/anaconda3/lib/python3.9/site-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)
# /opt/anaconda3/lib/python3.9/site-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)
# /opt/anaconda3/lib/python3.9/site-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)
# /opt/anaconda3/lib/python3.9/site-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)
# /opt/anaconda3/lib/python3.9/site-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)
# /opt/anaconda3/lib/python3.9/site-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)
# [(0,
#   '0.037*"star" + 0.034*"five" + 0.027*"spray" + 0.027*"great" + 0.017*"skin" + 0.015*"refresh" + 0.015*"like" + 0.010*"water" + 0.010*"face" + 0.010*"give"'),
#  (1,
#   '0.028*"nice" + 0.018*"skin" + 0.018*"recommend" + 0.017*"good" + 0.015*"face" + 0.013*"spray" + 0.011*"order" + 0.010*"use" + 0.008*"tip" + 0.008*"water"'),
#  (2,
#   '0.042*"water" + 0.028*"skin" + 0.015*"feel" + 0.014*"spray" + 0.009*"hair" + 0.008*"like" + 0.008*"day" + 0.007*"cool" + 0.007*"use" + 0.007*"face"'),
#  (3,
#   '0.027*"love" + 0.025*"bottle" + 0.024*"water" + 0.020*"face" + 0.020*"spray" + 0.018*"refresh" + 0.015*"skin" + 0.014*"good" + 0.011*"like" + 0.010*"give"'),
#  (4,
#   '0.075*"skin" + 0.029*"sensitive" + 0.026*"love" + 0.016*"great" + 0.014*"dry" + 0.014*"feel" + 0.011*"spray" + 0.011*"good" + 0.011*"use" + 0.010*"help"'),
#  (5,
#   '0.037*"skin" + 0.035*"love" + 0.033*"face" + 0.016*"water" + 0.015*"feel" + 0.014*"refresh" + 0.014*"use" + 0.014*"good" + 0.014*"mist" + 0.013*"spray"'),
#  (6,
#   '0.023*"good" + 0.023*"spray" + 0.022*"work" + 0.020*"face" + 0.016*"feel" + 0.015*"stop" + 0.013*"one" + 0.013*"skin" + 0.011*"bottle" + 0.011*"water"')]

# %%
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim_models.prepare(lda_model, bow_corpus, dic)
vis
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /opt/anaconda3/lib/python3.9/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /opt/anaconda3/lib/python3.9/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /opt/anaconda3/lib/python3.9/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /opt/anaconda3/lib/python3.9/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /opt/anaconda3/lib/python3.9/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /opt/anaconda3/lib/python3.9/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /opt/anaconda3/lib/python3.9/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 4     -0.067092 -0.039616       1        1  20.240657
# 5     -0.053292 -0.067619       2        1  16.858437
# 3      0.022969 -0.002136       3        1  15.874022
# 6      0.051881  0.034223       4        1  14.867528
# 2     -0.039389 -0.027862       5        1  13.913738
# 0      0.124132 -0.030895       6        1  12.799261
# 1     -0.039209  0.133904       7        1   5.446357, topic_info=          Term        Freq       Total Category  logprob  loglift
# 454       five   40.000000   40.000000  Default  30.0000  30.0000
# 120       star   56.000000   56.000000  Default  29.0000  29.0000
# 96        nice   28.000000   28.000000  Default  28.0000  28.0000
# 56   sensitive   68.000000   68.000000  Default  27.0000  27.0000
# 24        skin  246.000000  246.000000  Default  26.0000  26.0000
# ..         ...         ...         ...      ...      ...      ...
# 28        well    2.415576   38.239189   Topic7  -5.1333   0.1483
# 264       make    2.387935   42.775211   Topic7  -5.1448   0.0247
# 27         try    2.263332   28.432267   Topic7  -5.1984   0.3795
# 60      avenue    2.234994   30.989556   Topic7  -5.2110   0.2808
# 34      bottle    2.210452   60.327577   Topic7  -5.2220  -0.3964
#
# [497 rows x 6 columns], token_table=      Topic      Freq        Term
# term
# 30        2  0.242025  absolutely
# 30        3  0.403375  absolutely
# 30        6  0.403375  absolutely
# 1469      7  0.471458    accurate
# 175       1  0.649357        acne
# ...     ...       ...         ...
# 122       6  0.139370       would
# 122       7  0.046457       would
# 992       1  0.772460    xeracalm
# 639       5  0.406280         yes
# 639       6  0.609420         yes
#
# [930 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[5, 6, 4, 7, 3, 1, 2])

# %% [markdown]
# # STTM

# %%
def top_words(distribution, top_index, num_words):
    for topic in top_index:
        pairs = sorted([(k, v) for k, v in distribution[topic].items()], key=lambda x: x[1], reverse=True)
        print(f"Cluster {topic} : {pairs[:num_words]}")
        print('-'*30)

# %%
# Train STTM model
# Init of the Gibbs Sampling Dirichlet Mixture Model algorithm
# K = number of potential topic (which we don't know a priori)
# alpha = default
# beta = default
# n_iters = number of iterations

num_topic = 7

mgp = MovieGroupProcess(K=num_topic, alpha=0.1, beta=0.1, n_iters=30)
vocab = set(x for doc in corpus for x in doc)
n_terms = len(vocab)
y = mgp.fit(corpus, n_terms)
# Save model
with open('/Users/maxime/IronHack/FinalProject/STTM_model/all.model', "wb") as f:
    pickle.dump(mgp, f)
    f.close()
# Out:
# In stage 0: transferred 323 clusters with 7 clusters populated
# In stage 1: transferred 190 clusters with 7 clusters populated
# In stage 2: transferred 120 clusters with 7 clusters populated
# In stage 3: transferred 92 clusters with 7 clusters populated
# In stage 4: transferred 87 clusters with 7 clusters populated
# In stage 5: transferred 59 clusters with 7 clusters populated
# In stage 6: transferred 54 clusters with 7 clusters populated
# In stage 7: transferred 56 clusters with 7 clusters populated
# In stage 8: transferred 52 clusters with 7 clusters populated
# In stage 9: transferred 55 clusters with 7 clusters populated
# In stage 10: transferred 37 clusters with 7 clusters populated
# In stage 11: transferred 47 clusters with 7 clusters populated
# In stage 12: transferred 49 clusters with 7 clusters populated
# In stage 13: transferred 47 clusters with 7 clusters populated
# In stage 14: transferred 43 clusters with 7 clusters populated
# In stage 15: transferred 47 clusters with 7 clusters populated
# In stage 16: transferred 42 clusters with 7 clusters populated
# In stage 17: transferred 45 clusters with 7 clusters populated
# In stage 18: transferred 46 clusters with 7 clusters populated
# In stage 19: transferred 43 clusters with 7 clusters populated
# In stage 20: transferred 48 clusters with 7 clusters populated
# In stage 21: transferred 35 clusters with 7 clusters populated
# In stage 22: transferred 36 clusters with 7 clusters populated
# In stage 23: transferred 35 clusters with 7 clusters populated
# In stage 24: transferred 35 clusters with 7 clusters populated
# In stage 25: transferred 40 clusters with 7 clusters populated
# In stage 26: transferred 33 clusters with 7 clusters populated
# In stage 27: transferred 45 clusters with 7 clusters populated
# In stage 28: transferred 41 clusters with 7 clusters populated
# In stage 29: transferred 41 clusters with 7 clusters populated

# %%
# 7 cluster
doc_count = np.array(mgp.cluster_doc_count)
print('Number of documents per topic :', doc_count)
print('*'*20)
# Topics sorted by the number of document they are allocated to
top_index = doc_count.argsort()[-10:][::-1]
print('Most important clusters (by number of docs inside):', top_index)
print('*'*20)
# Show the top 5 words in term frequency for each cluster 
top_words(mgp.cluster_word_distribution, top_index, 5)
# Out:
# Number of documents per topic : [227  26   4  12 104  52  16]
# ********************
# Most important clusters (by number of docs inside): [0 4 5 1 6 3 2]
# ********************
# Cluster 0 : [('love', 107), ('skin', 98), ('good', 80), ('star', 58), ('refresh', 50)]
# ------------------------------
# Cluster 4 : [('skin', 149), ('water', 72), ('face', 67), ('feel', 61), ('spray', 60)]
# ------------------------------
# Cluster 5 : [('spray', 31), ('work', 29), ('bottle', 18), ('stop', 18), ('get', 17)]
# ------------------------------
# Cluster 1 : [('spray', 15), ('water', 14), ('like', 11), ('skin', 9), ('use', 8)]
# ------------------------------
# Cluster 6 : [('bottle', 18), ('face', 16), ('water', 15), ('love', 11), ('spray', 11)]
# ------------------------------
# Cluster 3 : [('skin', 18), ('water', 9), ('keep', 6), ('cool', 6), ('refresh', 4)]
# ------------------------------
# Cluster 2 : [('tip', 5), ('spray', 4), ('try', 3), ('water', 3), ('avenue', 2)]
# ------------------------------
